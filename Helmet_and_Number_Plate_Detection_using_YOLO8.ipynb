# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshpv/Helmet_and_Number_Plate_Detection_using_YOLO8/blob/main/Helmet_and_Number_Plate_Detection_using_YOLO8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d "aneesarom/rider-with-helmet-without-helmet-number-plate"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aneesarom/rider-with-helmet-without-helmet-number-plate
# License(s): apache-2.0
# ...
#  83% 62.0M/74.6M [00:00<00:00, 115MB/s]
# 100% 74.6M/74.6M [00:00<00:00, 116MB/s]

# %%
# !unzip /content/rider-with-helmet-without-helmet-number-plate.zip
# Out:
# Archive:  /content/rider-with-helmet-without-helmet-number-plate.zip
#   inflating: classes.txt
#   inflating: coco128.yaml
#   inflating: train/images/new1.jpg
#   inflating: train/images/new10.jpg
#   inflating: train/images/new100.jpg
#   inflating: train/images/new101.jpg
#   inflating: train/images/new102.jpg
#   inflating: train/images/new103.jpg
#   inflating: train/images/new106.jpg
#   inflating: train/images/new108.jpg
#   inflating: train/images/new109.jpg
#   inflating: train/images/new11.jpg
#   inflating: train/images/new110.jpg
#   inflating: train/images/new112.jpg
#   inflating: train/images/new114.jpg
#   inflating: train/images/new116.jpg
#   inflating: train/images/new117.jpg
#   inflating: train/images/new118.jpg
#   inflating: train/images/new119.jpg
#   inflating: train/images/new120.jpg
#   inflating: train/images/new121.jpg
#   inflating: train/images/new122.jpg
#   inflating: train/images/new123.jpg
#   inflating: train/images/new124.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 24.2 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/coco128.yaml epochs=10  project=/content/training_results name=results
# Out:
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
model=YOLO('/content/training_results/results2/weights/best.pt')
lst=model('/content/Traffic.jpeg')
lst[0].save("result.png")
# Out:
# image 1/1 /content/Traffic.jpeg: 448x640 2 with helmets, 20 riders, 38.1ms
# Speed: 3.5ms preprocess, 38.1ms inference, 580.4ms postprocess per image at shape (1, 3, 448, 640)
# 'result.png'

# %%
lst=model('/content/val/images/new94.jpg')
lst[0].save("result1.png")
# Out:
# image 1/1 /content/val/images/new94.jpg: 608x640 1 with helmet, 1 rider, 1 number plate, 16.8ms
# Speed: 2.6ms preprocess, 16.8ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 640)
# 'result1.png'

# %%
lst=model('/content/val/images/new73.jpg')
lst[0].save("result2.png")
# Out:
# image 1/1 /content/val/images/new73.jpg: 384x640 2 without helmets, 2 riders, 1 number plate, 11.7ms
# Speed: 5.8ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 'result2.png'

# %%
model.save("Helmet_detection.H5")

# %%
lst=model('/content/traffic2.jpg')
lst[0].save("result3.png")
# Out:
# 'result3.png'

# %% [markdown]
# Frame for detection

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('/content/traffic2.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# Frame Detected

# %%
image = cv2.imread('result3.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
lst=model('/content/Traffic4.jpeg')
lst[0].save("result4.png")
# Out:
# 'result4.png'
